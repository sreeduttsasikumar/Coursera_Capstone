# %% [markdown]
# <a href="https://colab.research.google.com/github/sreeduttsasikumar/Coursera_Capstone/blob/main/Sreedutt_Sasikumar_Capstone_Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <h1><center>Sreedutt Sasikumar Capstone Project</center></h1>
# In this notebook we are trying to execute the Capstone Project as part of IBM Professional Data Science course!!

# %%
import pandas as pd
import numpy as np

# %%
print("Hello Capstone Project Course!")
# Out:
# Hello Capstone Project Course!
